# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import cv2

# %%
dfVGG16_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/1/[Result]221002_TryBA_1_VGG16.csv")
dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/1/[Result]221002_TryBA_1_ResNet50.csv")
dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/1/[Result]221002_TryBA_1_MobileNet.csv")
dfVGG19_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/1/[Result]221002_TryBA_1_VGG19.csv")
dfResNet50v2_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/1/[Result]221002_TryBA_1_ResNet50v2.csv")

dfVGG16_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/2/[Result]221002_TryBA_2_VGG16.csv")
dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/2/[Result]221002_TryBA_2_ResNet50.csv")
dfMobileNet_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/2/[Result]221002_TryBA_2_MobileNet.csv")
dfVGG19_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/2/[Result]221002_TryBA_2_VGG19.csv")
dfResNet50v2_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/2/[Result]221002_TryBA_2_ResNet50v2.csv")

dfVGG16_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/3/[Result]221002_TryBA_3_VGG16.csv")
dfResNet50_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/3/[Result]221002_TryBA_3_ResNet50.csv")
dfMobileNet_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/3/[Result]221002_TryBA_3_MobileNet.csv")
dfVGG19_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/3/[Result]221002_TryBA_3_VGG19.csv")
dfResNet50v2_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/3/[Result]221002_TryBA_3_ResNet50v2.csv")

dfVGG16_4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/4/[Result]221002_TryBA_4_VGG16.csv")
dfResNet50_4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/4/[Result]221002_TryBA_4_ResNet50.csv")
dfMobileNet_4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/4/[Result]221002_TryBA_4_MobileNet.csv")
dfVGG19_4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/4/[Result]221002_TryBA_4_VGG19.csv")
dfResNet50v2_4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/4/[Result]221002_TryBA_4_ResNet50v2.csv")

dfVGG16_5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/5/[Result]221002_TryBA_5_VGG16.csv")
dfResNet50_5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/5/[Result]221002_TryBA_5_ResNet50.csv")
dfMobileNet_5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/5/[Result]221002_TryBA_5_MobileNet.csv")
dfVGG19_5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/5/[Result]221002_TryBA_5_VGG19.csv")
dfResNet50v2_5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221002_TryBA_csv/5/[Result]221002_TryBA_5_ResNet50v2.csv")

# %%
xBar = [i for i in range(0, 100)]

# %%
# VGG16 Result
# VGG16 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Time"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Time"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Time"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Time"], color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Time"], color = "purple")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Time"], color = "purple")

ax5 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Time"], color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Time"], color = "red")

ax1.set_title("TryBA_dfVGG16 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3', 'VGG16_4', 'VGG16_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_TimeGraph.png')
files.download("TryBA_VGG16_TimeGraph.png")
plt.show()

# VGG16 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Loss"]/10, color = "purple")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Loss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Loss"]/10, color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Loss"]/10, color = "red")

ax1.set_title("TryBA_dfVGG16 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3', 'VGG16_4', 'VGG16_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_LossGraph.png')
files.download("TryBA_VGG16_LossGraph.png")
plt.show()

# VGG16 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Accuracy"], color = "purple")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Accuracy"], color = "purple")

ax5 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Accuracy"], color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Accuracy"], color = "red")


ax1.set_title("TryBA_dfVGG16 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3', 'VGG16_4', 'VGG16_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_AccuracyGraph.png')
files.download("TryBA_VGG16_AccuracyGraph.png")
plt.show()


# VGG16 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valLoss"]/10, color = "purple")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valLoss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valLoss"]/10, color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valLoss"]/10, color = "red")

ax1.set_title("TryBA_dfVGG16 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3', 'VGG16_4', 'VGG16_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_valLossGraph.png')
files.download("TryBA_VGG16_valLossGraph.png")
plt.show()

# VGG16 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valAccuracy"], color = "purple")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valAccuracy"], color = "purple")

ax5 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_dfVGG16 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3', 'VGG16_4', 'VGG16_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_valAccuracyGraph.png')
files.download("TryBA_VGG16_valAccuracyGraph.png")
plt.show()

# %%
# ResNet50 Result
# ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Time"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Time"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Time"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Time"], color = "purple")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Time"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Time"], color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Time"], color = "red")

ax1.set_title("TryBA_dfResNet50 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3', 'ResNet50_4', 'ResNet50_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_TimeGraph.png')
files.download("TryBA_ResNet50_TimeGraph.png")
plt.show()

# ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Loss"]/10, color = "purple")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Loss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Loss"]/10, color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Loss"]/10, color = "red")

ax1.set_title("TryBA_dfResNet50 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3', 'ResNet50_4', 'ResNet50_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_LossGraph.png')
files.download("TryBA_ResNet50_LossGraph.png")
plt.show()

# ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Accuracy"], color = "purple")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Accuracy"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Accuracy"], color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Accuracy"], color = "red")


ax1.set_title("TryBA_dfResNet50 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3', 'ResNet50_4', 'ResNet50_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_AccuracyGraph.png')
files.download("TryBA_ResNet50_AccuracyGraph.png")
plt.show()


# ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valLoss"]/10, color = "purple")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valLoss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valLoss"]/10, color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valLoss"]/10, color = "red")

ax1.set_title("TryBA_dfResNet50 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3', 'ResNet50_4', 'ResNet50_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_valLossGraph.png')
files.download("TryBA_ResNet50_valLossGraph.png")
plt.show()

# ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valAccuracy"], color = "purple")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valAccuracy"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_dfResNet50 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3', 'ResNet50_4', 'ResNet50_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_valAccuracyGraph.png')
files.download("TryBA_ResNet50_valAccuracyGraph.png")
plt.show()

# %%
# MobileNet Result
# MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Time"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Time"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Time"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Time"], color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Time"], color = "purple")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Time"], color = "purple")

ax5 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Time"], color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Time"], color = "red")

ax1.set_title("TryBA_dfMobileNet - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3', 'MobileNet_4', 'MobileNet_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_TimeGraph.png')
files.download("TryBA_MobileNet_TimeGraph.png")
plt.show()

# MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Loss"]/10, color = "purple")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Loss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Loss"]/10, color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Loss"]/10, color = "red")

ax1.set_title("TryBA_dfMobileNet - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3', 'MobileNet_4', 'MobileNet_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_LossGraph.png')
files.download("TryBA_MobileNet_LossGraph.png")
plt.show()

# MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Accuracy"], color = "purple")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Accuracy"], color = "purple")

ax5 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Accuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Accuracy"], color = "red")


ax1.set_title("TryBA_dfMobileNet - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3', 'MobileNet_4', 'MobileNet_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_AccuracyGraph.png')
files.download("TryBA_MobileNet_AccuracyGraph.png")
plt.show()


# MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valLoss"]/10, color = "purple")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valLoss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valLoss"]/10, color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valLoss"]/10, color = "red")

ax1.set_title("TryBA_dfMobileNet - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3', 'MobileNet_4', 'MobileNet_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_valLossGraph.png')
files.download("TryBA_MobileNet_valLossGraph.png")
plt.show()

# MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valAccuracy"], color = "purple")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valAccuracy"], color = "purple")

ax5 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_dfMobileNet - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3', 'MobileNet_4', 'MobileNet_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_valAccuracyGraph.png')
files.download("TryBA_MobileNet_valAccuracyGraph.png")
plt.show()

# %%
# VGG19 Result
# VGG19 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Time"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Time"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Time"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Time"], color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Time"], color = "purple")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Time"], color = "purple")

ax5 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Time"], color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Time"], color = "red")

ax1.set_title("TryBA_dfVGG19 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3', 'VGG19_4', 'VGG19_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_TimeGraph.png')
files.download("TryBA_VGG19_TimeGraph.png")
plt.show()

# VGG19 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Loss"]/10, color = "purple")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Loss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Loss"]/10, color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Loss"]/10, color = "red")

ax1.set_title("TryBA_dfVGG19 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3', 'VGG19_4', 'VGG19_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_LossGraph.png')
files.download("TryBA_VGG19_LossGraph.png")
plt.show()

# VGG19 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Accuracy"], color = "purple")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Accuracy"], color = "purple")

ax5 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Accuracy"], color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Accuracy"], color = "red")


ax1.set_title("TryBA_dfVGG19 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3', 'VGG19_4', 'VGG19_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_AccuracyGraph.png')
files.download("TryBA_VGG19_AccuracyGraph.png")
plt.show()


# VGG19 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valLoss"]/10, color = "purple")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valLoss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valLoss"]/10, color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valLoss"]/10, color = "red")

ax1.set_title("TryBA_dfVGG19 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3', 'VGG19_4', 'VGG19_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_valLossGraph.png')
files.download("TryBA_VGG19_valLossGraph.png")
plt.show()

# VGG19 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valAccuracy"], color = "purple")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valAccuracy"], color = "purple")

ax5 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_dfVGG19 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3', 'VGG19_4', 'VGG19_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_valAccuracyGraph.png')
files.download("TryBA_VGG19_valAccuracyGraph.png")
plt.show()

# %%
# ResNet50v2 Result
# ResNet50v2 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Time"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Time"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Time"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Time"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Time"], color = "purple")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Time"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Time"], color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Time"], color = "red")

ax1.set_title("TryBA_dfResNet50v2 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3', 'ResNet50v2_4', 'ResNet50v2_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_TimeGraph.png')
files.download("TryBA_ResNet50v2_TimeGraph.png")
plt.show()

# ResNet50v2 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Loss"]/10, color = "purple")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Loss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Loss"]/10, color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Loss"]/10, color = "red")

ax1.set_title("TryBA_dfResNet50v2 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3', 'ResNet50v2_4', 'ResNet50v2_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_LossGraph.png')
files.download("TryBA_ResNet50v2_LossGraph.png")
plt.show()

# ResNet50v2 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Accuracy"], color = "purple")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Accuracy"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Accuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Accuracy"], color = "red")


ax1.set_title("TryBA_dfResNet50v2 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3', 'ResNet50v2_4', 'ResNet50v2_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_AccuracyGraph.png')
files.download("TryBA_ResNet50v2_AccuracyGraph.png")
plt.show()


# ResNet50v2 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valLoss"]/10, color = "purple")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valLoss"]/10, color = "purple")

ax5 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valLoss"]/10, color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valLoss"]/10, color = "red")

ax1.set_title("TryBA_dfResNet50v2 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3', 'ResNet50v2_4', 'ResNet50v2_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_valLossGraph.png')
files.download("TryBA_ResNet50v2_valLossGraph.png")
plt.show()

# ResNet50v2 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valAccuracy"], color = "purple")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valAccuracy"], color = "purple")

ax5 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_dfResNet50v2 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3', 'ResNet50v2_4', 'ResNet50v2_5'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_valAccuracyGraph.png')
files.download("TryBA_ResNet50v2_valAccuracyGraph.png")
plt.show()

# %%
# TryBA_VGG16_Result
# VGG16_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG16_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG16_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG16_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG16_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG16_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG16_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_4
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_4, x=xBar, y=dfVGG16_4["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG16_4")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_4_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG16_4_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_5
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_5, x=xBar, y=dfVGG16_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG16_5")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG16_5_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG16_5_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryBA_ResNet50_Result
# ResNet50_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_4
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_4, x=xBar, y=dfResNet50_4["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50_4")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_4_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50_4_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_5
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_5, x=xBar, y=dfResNet50_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50_5")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50_5_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50_5_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryBA_MobileNet_Result
# MobileNet_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryBA_MobileNet_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_MobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "red")

ax1.set_title("TryBA_MobileNet_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_MobileNet_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "red")

ax1.set_title("TryBA_MobileNet_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_MobileNet_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_4
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_4, x=xBar, y=dfMobileNet_4["valAccuracy"], color = "red")

ax1.set_title("TryBA_MobileNet_4")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_4_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_MobileNet_4_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_5
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_5, x=xBar, y=dfMobileNet_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_MobileNet_5")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_MobileNet_5_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_MobileNet_5_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryBA_VGG19_Result
# VGG19_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG19_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG19_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG19_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG19_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG19_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG19_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_4
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_4, x=xBar, y=dfVGG19_4["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG19_4")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_4_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG19_4_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_5
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_5, x=xBar, y=dfVGG19_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_VGG19_5")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_VGG19_5_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_VGG19_5_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryBA_ResNet50v2_Result
# ResNet50v2_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50v2_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50v2_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50v2_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50v2_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50v2_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50v2_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_4
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_4, x=xBar, y=dfResNet50v2_4["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50v2_4")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_4_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50v2_4_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_5
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_5, x=xBar, y=dfResNet50v2_5["valAccuracy"], color = "red")

ax1.set_title("TryBA_ResNet50v2_5")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryBA_ResNet50v2_5_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryBA_ResNet50v2_5_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()
