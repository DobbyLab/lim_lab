# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import cv2

# %%
dfVGG16_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_A(VGG16).csv")
dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_B(ResNet50).csv")
dfInceptionV3_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_C(InceptionV3).csv")
dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_D(MobileNet).csv")
dfVGG19_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_E(VGG19).csv")
dfResNet50v2_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_F(ResNet50v2).csv")
dfXception_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/1/1_220928__Write5_G(Xception).csv")

dfVGG16_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_A(VGG16).csv")
dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_B(ResNet50).csv")
dfInceptionV3_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_C(InceptionV3).csv")
dfMobileNet_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_D(MobileNet).csv")
dfVGG19_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_E(VGG19).csv")
dfResNet50v2_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_F(ResNet50v2).csv")
dfXception_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/2/2_220928__Write5_G(Xception).csv")

dfVGG16_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/3/3_220928__Write5_A(VGG16).csv")
dfResNet50_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/3/3_220928__Write5_B(ResNet50).csv")
dfMobileNet_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/3/3_220928__Write5_D(MobileNet).csv")
dfVGG19_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/3/3_220928__Write5_E(VGG19).csv")
dfResNet50v2_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/220928_TryAA_csv/3/3_220928__Write5_F(ResNet50v2).csv")

# %%
xBar = [i for i in range(0, 100)]

# %%
# VGG16 Result
# VGG16 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Time"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Time"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Time"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Time"], color = "orange")

ax1.set_title("TryAA_dfVGG16 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_TimeGraph.png')
files.download("TryAA_VGG16_TimeGraph.png")
plt.show()

# VGG16 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "orange")

ax1.set_title("TryAA_dfVGG16 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_LossGraph.png')
files.download("TryAA_VGG16_LossGraph.png")
plt.show()

# VGG16 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "orange")

ax1.set_title("TryAA_dfVGG16 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_AccuracyGraph.png')
files.download("TryAA_VGG16_AccuracyGraph.png")
plt.show()


# VGG16 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")

ax1.set_title("TryAA_dfVGG16 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_valLossGraph.png')
files.download("TryAA_VGG16_valLossGraph.png")
plt.show()

# VGG16 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "orange")

ax1.set_title("TryAA_dfVGG16 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG16_1', 'VGG16_2', 'VGG16_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_valAccuracyGraph.png')
files.download("TryAA_VGG16_valAccuracyGraph.png")
plt.show()

# %%
# ResNet50 Result
# ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Time"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Time"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Time"], color = "orange")

ax1.set_title("TryAA_dfResNet50 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_TimeGraph.png')
files.download("TryAA_ResNet50_TimeGraph.png")
plt.show()

# ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "orange")

ax1.set_title("TryAA_dfResNet50 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_LossGraph.png')
files.download("TryAA_ResNet50_LossGraph.png")
plt.show()

# ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "orange")

ax1.set_title("TryAA_dfResNet50 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_AccuracyGraph.png')
files.download("TryAA_ResNet50_AccuracyGraph.png")
plt.show()


# ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")

ax1.set_title("TryAA_dfResNet50 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_valLossGraph.png')
files.download("TryAA_ResNet50_valLossGraph.png")
plt.show()

# ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "orange")

ax1.set_title("TryAA_dfResNet50 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50_1', 'ResNet50_2', 'ResNet50_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_valAccuracyGraph.png')
files.download("TryAA_ResNet50_valAccuracyGraph.png")
plt.show()

# %%
# InceptionV3 Result
# InceptionV3 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Time"], color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Time"], color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Time"], color = "green")

ax1.set_title("TryAA_dfInceptionV3 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['InceptionV3_1', 'InceptionV3_2', 'InceptionV3_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_TimeGraph.png')
files.download("TryAA_InceptionV3_TimeGraph.png")
plt.show()

# InceptionV3 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Loss"]/10, color = "green")

ax1.set_title("TryAA_dfInceptionV3 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['InceptionV3_1', 'InceptionV3_2', 'InceptionV3_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_LossGraph.png')
files.download("TryAA_InceptionV3_LossGraph.png")
plt.show()

# InceptionV3 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Accuracy"], color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Accuracy"], color = "green")

ax1.set_title("TryAA_dfInceptionV3 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['InceptionV3_1', 'InceptionV3_2', 'InceptionV3_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_AccuracyGraph.png')
files.download("TryAA_InceptionV3_AccuracyGraph.png")
plt.show()


# InceptionV3 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valLoss"]/10, color = "green")

ax1.set_title("TryAA_dfInceptionV3 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['InceptionV3_1', 'InceptionV3_2', 'InceptionV3_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_valLossGraph.png')
files.download("TryAA_InceptionV3_valLossGraph.png")
plt.show()

# InceptionV3 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valAccuracy"], color = "green")

ax1.set_title("TryAA_dfInceptionV3 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['InceptionV3_1', 'InceptionV3_2', 'InceptionV3_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_valAccuracyGraph.png')
files.download("TryAA_InceptionV3_valAccuracyGraph.png")
plt.show()

# %%
# MobileNet Result
# MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Time"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Time"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Time"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Time"], color = "orange")

ax1.set_title("TryAA_dfMobileNet - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_TimeGraph.png')
files.download("TryAA_MobileNet_TimeGraph.png")
plt.show()

# MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "orange")

ax1.set_title("TryAA_dfMobileNet - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_LossGraph.png')
files.download("TryAA_MobileNet_LossGraph.png")
plt.show()

# MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "orange")

ax1.set_title("TryAA_dfMobileNet - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_AccuracyGraph.png')
files.download("TryAA_MobileNet_AccuracyGraph.png")
plt.show()


# MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")

ax1.set_title("TryAA_dfMobileNet - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_valLossGraph.png')
files.download("TryAA_MobileNet_valLossGraph.png")
plt.show()

# MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "orange")

ax1.set_title("TryAA_dfMobileNet - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['MobileNet_1', 'MobileNet_2', 'MobileNet_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_valAccuracyGraph.png')
files.download("TryAA_MobileNet_valAccuracyGraph.png")
plt.show()

# %%
# VGG19 Result
# VGG19 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Time"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Time"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Time"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Time"], color = "orange")

ax1.set_title("TryAA_dfVGG19 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_TimeGraph.png')
files.download("TryAA_VGG19_TimeGraph.png")
plt.show()

# VGG19 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "orange")

ax1.set_title("TryAA_dfVGG19 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_LossGraph.png')
files.download("TryAA_VGG19_LossGraph.png")
plt.show()

# VGG19 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "orange")

ax1.set_title("TryAA_dfVGG19 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_AccuracyGraph.png')
files.download("TryAA_VGG19_AccuracyGraph.png")
plt.show()


# VGG19 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")

ax1.set_title("TryAA_dfVGG19 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_valLossGraph.png')
files.download("TryAA_VGG19_valLossGraph.png")
plt.show()

# VGG19 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "orange")

ax1.set_title("TryAA_dfVGG19 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['VGG19_1', 'VGG19_2', 'VGG19_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_valAccuracyGraph.png')
files.download("TryAA_VGG19_valAccuracyGraph.png")
plt.show()

# %%
# ResNet50v2 Result
# ResNet50v2 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Time"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Time"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Time"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Time"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Time"], color = "orange")

ax1.set_title("TryAA_dfResNet50v2 - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_TimeGraph.png')
files.download("TryAA_ResNet50v2_TimeGraph.png")
plt.show()

# ResNet50v2 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "orange")

ax1.set_title("TryAA_dfResNet50v2 - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_LossGraph.png')
files.download("TryAA_ResNet50v2_LossGraph.png")
plt.show()

# ResNet50v2 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "orange")

ax1.set_title("TryAA_dfResNet50v2 - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_AccuracyGraph.png')
files.download("TryAA_ResNet50v2_AccuracyGraph.png")
plt.show()


# ResNet50v2 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")

ax1.set_title("TryAA_dfResNet50v2 - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_valLossGraph.png')
files.download("TryAA_ResNet50v2_valLossGraph.png")
plt.show()

# ResNet50v2 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "orange")

ax1.set_title("TryAA_dfResNet50v2 - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['ResNet50v2_1', 'ResNet50v2_2', 'ResNet50v2_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_valAccuracyGraph.png')
files.download("TryAA_ResNet50v2_valAccuracyGraph.png")
plt.show()

# %%
# Xception Result
# Xception Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["Time"], color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["Time"], color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["Time"], color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["Time"], color = "green")

ax1.set_title("TryAA_dfXception - Time")
plt.xlabel("Epoch")
plt.legend(labels = ['Xception_1', 'Xception_2', 'Xception_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_TimeGraph.png')
files.download("TryAA_Xception_TimeGraph.png")
plt.show()

# Xception Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["Loss"]/10, color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["Loss"]/10, color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["Loss"]/10, color = "green")

ax1.set_title("TryAA_dfXception - Loss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Xception_1', 'Xception_2', 'Xception_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_LossGraph.png')
files.download("TryAA_Xception_LossGraph.png")
plt.show()

# Xception Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["Accuracy"], color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["Accuracy"], color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["Accuracy"], color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["Accuracy"], color = "green")

ax1.set_title("TryAA_dfXception - Accuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Xception_1', 'Xception_2', 'Xception_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_AccuracyGraph.png')
files.download("TryAA_Xception_AccuracyGraph.png")
plt.show()


# Xception valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["valLoss"]/10, color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["valLoss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["valLoss"]/10, color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["valLoss"]/10, color = "green")

ax1.set_title("TryAA_dfXception - valLoss")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Xception_1', 'Xception_2', 'Xception_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_valLossGraph.png')
files.download("TryAA_Xception_valLossGraph.png")
plt.show()

# Xception valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["valAccuracy"], color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["valAccuracy"], color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["valAccuracy"], color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["valAccuracy"], color = "green")

ax1.set_title("TryAA_dfXception - valAccuracy")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Xception_1', 'Xception_2', 'Xception_3'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_valAccuracyGraph.png')
files.download("TryAA_Xception_valAccuracyGraph.png")
plt.show()

# %%
# TryAA_VGG16_Result
# VGG16_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_1, x=xBar, y=dfVGG16_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG16_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG16_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_2, x=xBar, y=dfVGG16_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG16_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG16_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG16_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG16_3, x=xBar, y=dfVGG16_3["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG16_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG16_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG16_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_ResNet50_Result
# ResNet50_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_1, x=xBar, y=dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_2, x=xBar, y=dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50_3, x=xBar, y=dfResNet50_3["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_InceptionV3_Result
# InceptionV3_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Accuracy"], color = "green")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfInceptionV3_1, x=xBar, y=dfInceptionV3_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_InceptionV3_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_InceptionV3_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# InceptionV3_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Accuracy"], color = "green")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfInceptionV3_2, x=xBar, y=dfInceptionV3_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_InceptionV3_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_InceptionV3_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_InceptionV3_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_MobileNet_Result
# MobileNet_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_1, x=xBar, y=dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_MobileNet_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_MobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_2, x=xBar, y=dfMobileNet_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_MobileNet_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_MobileNet_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# MobileNet_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "green")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfMobileNet_3, x=xBar, y=dfMobileNet_3["valAccuracy"], color = "red")

ax1.set_title("TryAA_MobileNet_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_MobileNet_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_MobileNet_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_VGG19_Result
# VGG19_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_1, x=xBar, y=dfVGG19_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG19_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG19_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_2, x=xBar, y=dfVGG19_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG19_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG19_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# VGG19_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "green")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfVGG19_3, x=xBar, y=dfVGG19_3["valAccuracy"], color = "red")

ax1.set_title("TryAA_VGG19_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_VGG19_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_VGG19_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_ResNet50v2_Result
# ResNet50v2_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_1, x=xBar, y=dfResNet50v2_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50v2_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50v2_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_2, x=xBar, y=dfResNet50v2_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50v2_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50v2_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# ResNet50v2_3
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "blue")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "green")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "red")
sns.scatterplot(data=dfResNet50v2_3, x=xBar, y=dfResNet50v2_3["valAccuracy"], color = "red")

ax1.set_title("TryAA_ResNet50v2_3")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_ResNet50v2_3_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_ResNet50v2_3_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryAA_Xception_Result
# Xception_1
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["Loss"] /10, color = "blue")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["Accuracy"], color = "green")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfXception_1, x=xBar, y=dfXception_1["valAccuracy"], color = "red")
sns.scatterplot(data=dfXception_1, x=xBar, y=dfXception_1["valAccuracy"], color = "red")

ax1.set_title("TryAA_Xception_1")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_Xception_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# Xception_2
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["Loss"]/10, color = "blue")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["Loss"]/10, color = "blue")

ax2 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["Accuracy"], color = "green")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=dfXception_2, x=xBar, y=dfXception_2["valAccuracy"], color = "red")
sns.scatterplot(data=dfXception_2, x=xBar, y=dfXception_2["valAccuracy"], color = "red")

ax1.set_title("TryAA_Xception_2")
plt.xlabel("Epoch")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryAA_Xception_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryAA_Xception_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()
