# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import cv2

# %%
xBar = [i for i in range(0, 250)]

# %%
# ResNet50: 8, MobileNet: 4
# total: 12
# file: 12 + 40(5 * 8) + 1 = 53

Gaussian_5_dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/2/TryCC_2_ResNet50_1.csv")
Gaussian_5_dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/2/TryCC_2_ResNet50_2.csv")
Gaussian_5_dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/2/TryCC_2_MobileNet_1.csv")

Gaussian_7_dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/3/TryCC_3_ResNet50_1.csv")
Gaussian_7_dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/3/TryCC_3_ResNet50_2.csv")
Gaussian_7_dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/3/TryCC_3_MobileNet_1.csv")

Median_5_dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/4/TryCC_4_ResNet50_1.csv")
Median_5_dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/4/TryCC_4_ResNet50_2.csv")
Median_5_dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/4/TryCC_4_MobileNet_1.csv")

Median_7_dfResNet50_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/5/TryCC_5_ResNet50_1.csv")
Median_7_dfResNet50_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/5/TryCC_5_ResNet50_2.csv")
Median_7_dfMobileNet_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lim_Lab/221025_TryCC_csv/5/TryCC_5_MobileNet_1.csv")

# %%
# TryCC_Gaussian_5_ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Time"], color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Time"], color = "red")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Time"], color = "green")

ax1.set_title("TryCC_Gaussian_5_ResNet50_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(11, 25)
plt.legend(labels = ['Gaussian_5_ResNet50_1', 'Gaussian_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_ResNet50_224_Time.png')
files.download("TryCC_Gaussian_5_ResNet50_224_Time.png")
plt.show()

# TryCC_Gaussian_5_MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Time"], color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Time"], color = "red")

ax1.set_title("TryCC_Gaussian_5_MobileNet_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_MobileNet_224_Time.png')
files.download("TryCC_Gaussian_5_MobileNet_224_Time.png")
plt.show()


# TryCC_Gaussian_7_ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Time"], color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Time"], color = "red")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Time"], color = "green")

ax1.set_title("TryCC_Gaussian_7_ResNet50_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(11, 25)
plt.legend(labels = ['Gaussian_7_ResNet50_1', 'Gaussian_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_ResNet50_224_Time.png')
files.download("TryCC_Gaussian_7_ResNet50_224_Time.png")
plt.show()


# TryCC_Gaussian_7_MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Time"], color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Time"], color = "red")

ax1.set_title("TryCC_Gaussian_7_MobileNet_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_MobileNet_224_Time.png')
files.download("TryCC_Gaussian_7_MobileNet_224_Time.png")
plt.show()

# TryCC_Median_5_ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Time"], color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Time"], color = "red")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Time"], color = "green")

ax1.set_title("TryCC_Median_5_ResNet50_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(11, 25)
plt.legend(labels = ['Median_5_ResNet50_1', 'Median_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_ResNet50_224_Time.png')
files.download("TryCC_Median_5_ResNet50_224_Time.png")
plt.show()

# TryCC_Median_5_MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Time"], color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Time"], color = "red")

ax1.set_title("TryCC_Median_5_MobileNet_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_MobileNet_224_Time.png')
files.download("TryCC_Median_5_MobileNet_224_Time.png")
plt.show()


# TryCC_Median_7_ResNet50 Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Time"], color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Time"], color = "red")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Time"], color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Time"], color = "green")

ax1.set_title("TryCC_Median_7_ResNet50_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(11, 25)
plt.legend(labels = ['Median_7_ResNet50_1', 'Median_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_ResNet50_224_Time.png')
files.download("TryCC_Median_7_ResNet50_224_Time.png")
plt.show()


# TryCC_Median_7_MobileNet Time
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Time"], color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Time"], color = "red")

ax1.set_title("TryCC_Median_7_MobileNet_224 - Time")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_MobileNet_224_Time.png')
files.download("TryCC_Median_7_MobileNet_224_Time.png")
plt.show()

# %%
# TryCC_Gaussian_5_ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Loss"] / 10, color = "red")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Loss"] / 10, color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Loss"] / 10, color = "green")

ax1.set_title("TryCC_Gaussian_5_ResNet50_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_ResNet50_1', 'Gaussian_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_ResNet50_224_Loss.png')
files.download("TryCC_Gaussian_5_ResNet50_224_Loss.png")
plt.show()

# TryCC_Gaussian_5_MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Loss"] / 10, color = "red")

ax1.set_title("TryCC_Gaussian_5_MobileNet_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_MobileNet_224_Loss.png')
files.download("TryCC_Gaussian_5_MobileNet_224_Loss.png")
plt.show()


# TryCC_Gaussian_7_ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Loss"] / 10, color = "red")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Loss"] / 10, color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Loss"] / 10, color = "green")

ax1.set_title("TryCC_Gaussian_7_ResNet50_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_ResNet50_1', 'Gaussian_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_ResNet50_224_Loss.png')
files.download("TryCC_Gaussian_7_ResNet50_224_Loss.png")
plt.show()


# TryCC_Gaussian_7_MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Loss"] / 10, color = "red")

ax1.set_title("TryCC_Gaussian_7_MobileNet_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_MobileNet_224_Loss.png')
files.download("TryCC_Gaussian_7_MobileNet_224_Loss.png")
plt.show()

# TryCC_Median_5_ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Loss"] / 10, color = "red")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Loss"] / 10, color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Loss"] / 10, color = "green")

ax1.set_title("TryCC_Median_5_ResNet50_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_ResNet50_1', 'Median_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_ResNet50_224_Loss.png')
files.download("TryCC_Median_5_ResNet50_224_Loss.png")
plt.show()

# TryCC_Median_5_MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Loss"] / 10, color = "red")

ax1.set_title("TryCC_Median_5_MobileNet_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_MobileNet_224_Loss.png')
files.download("TryCC_Median_5_MobileNet_224_Loss.png")
plt.show()


# TryCC_Median_7_ResNet50 Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Loss"] / 10, color = "red")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Loss"] / 10, color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Loss"] / 10, color = "green")

ax1.set_title("TryCC_Median_7_ResNet50_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_ResNet50_1', 'Median_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_ResNet50_224_Loss.png')
files.download("TryCC_Median_7_ResNet50_224_Loss.png")
plt.show()


# TryCC_Median_7_MobileNet Loss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Loss"] / 10, color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Loss"] / 10, color = "red")

ax1.set_title("TryCC_Median_7_MobileNet_224 - Loss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_MobileNet_224_Loss.png')
files.download("TryCC_Median_7_MobileNet_224_Loss.png")
plt.show()

# %%
# TryCC_Gaussian_5_ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Accuracy"] , color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Accuracy"] , color = "red")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Accuracy"] , color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Accuracy"] , color = "green")

ax1.set_title("TryCC_Gaussian_5_ResNet50_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_ResNet50_1', 'Gaussian_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_ResNet50_224_Accuracy.png')
files.download("TryCC_Gaussian_5_ResNet50_224_Accuracy.png")
plt.show()

# TryCC_Gaussian_5_MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Accuracy"] , color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Accuracy"] , color = "red")

ax1.set_title("TryCC_Gaussian_5_MobileNet_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_MobileNet_224_Accuracy.png')
files.download("TryCC_Gaussian_5_MobileNet_224_Accuracy.png")
plt.show()


# TryCC_Gaussian_7_ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Accuracy"] , color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Accuracy"] , color = "red")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Accuracy"] , color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Accuracy"] , color = "green")

ax1.set_title("TryCC_Gaussian_7_ResNet50_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_ResNet50_1', 'Gaussian_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_ResNet50_224_Accuracy.png')
files.download("TryCC_Gaussian_7_ResNet50_224_Accuracy.png")
plt.show()


# TryCC_Gaussian_7_MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Accuracy"] , color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Accuracy"] , color = "red")

ax1.set_title("TryCC_Gaussian_7_MobileNet_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_MobileNet_224_Accuracy.png')
files.download("TryCC_Gaussian_7_MobileNet_224_Accuracy.png")
plt.show()

# TryCC_Median_5_ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Accuracy"] , color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Accuracy"] , color = "red")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Accuracy"] , color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Accuracy"] , color = "green")

ax1.set_title("TryCC_Median_5_ResNet50_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_ResNet50_1', 'Median_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_ResNet50_224_Accuracy.png')
files.download("TryCC_Median_5_ResNet50_224_Accuracy.png")
plt.show()

# TryCC_Median_5_MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Accuracy"] , color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Accuracy"] , color = "red")

ax1.set_title("TryCC_Median_5_MobileNet_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_MobileNet_224_Accuracy.png')
files.download("TryCC_Median_5_MobileNet_224_Accuracy.png")
plt.show()


# TryCC_Median_7_ResNet50 Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Accuracy"] , color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Accuracy"] , color = "red")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Accuracy"] , color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Accuracy"] , color = "green")

ax1.set_title("TryCC_Median_7_ResNet50_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_ResNet50_1', 'Median_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_ResNet50_224_Accuracy.png')
files.download("TryCC_Median_7_ResNet50_224_Accuracy.png")
plt.show()


# TryCC_Median_7_MobileNet Accuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Accuracy"] , color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Accuracy"] , color = "red")

ax1.set_title("TryCC_Median_7_MobileNet_224 - Accuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_MobileNet_224_Accuracy.png')
files.download("TryCC_Median_7_MobileNet_224_Accuracy.png")
plt.show()

# %%
# TryCC_Gaussian_5_ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valLoss"] / 10, color = "red")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valLoss"] / 10, color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valLoss"] / 10, color = "green")

ax1.set_title("TryCC_Gaussian_5_ResNet50_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_ResNet50_1', 'Gaussian_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_ResNet50_224_valLoss.png')
files.download("TryCC_Gaussian_5_ResNet50_224_valLoss.png")
plt.show()

# TryCC_Gaussian_5_MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valLoss"] / 10, color = "red")

ax1.set_title("TryCC_Gaussian_5_MobileNet_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_MobileNet_224_valLoss.png')
files.download("TryCC_Gaussian_5_MobileNet_224_valLoss.png")
plt.show()


# TryCC_Gaussian_7_ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valLoss"] / 10, color = "red")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valLoss"] / 10, color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valLoss"] / 10, color = "green")

ax1.set_title("TryCC_Gaussian_7_ResNet50_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_ResNet50_1', 'Gaussian_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_ResNet50_224_valLoss.png')
files.download("TryCC_Gaussian_7_ResNet50_224_valLoss.png")
plt.show()


# TryCC_Gaussian_7_MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valLoss"] / 10, color = "red")

ax1.set_title("TryCC_Gaussian_7_MobileNet_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_MobileNet_224_valLoss.png')
files.download("TryCC_Gaussian_7_MobileNet_224_valLoss.png")
plt.show()

# TryCC_Median_5_ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valLoss"] / 10, color = "red")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valLoss"] / 10, color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valLoss"] / 10, color = "green")

ax1.set_title("TryCC_Median_5_ResNet50_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_ResNet50_1', 'Median_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_ResNet50_224_valLoss.png')
files.download("TryCC_Median_5_ResNet50_224_valLoss.png")
plt.show()

# TryCC_Median_5_MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valLoss"] / 10, color = "red")

ax1.set_title("TryCC_Median_5_MobileNet_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_MobileNet_224_valLoss.png')
files.download("TryCC_Median_5_MobileNet_224_valLoss.png")
plt.show()


# TryCC_Median_7_ResNet50 valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valLoss"] / 10, color = "red")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valLoss"] / 10, color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valLoss"] / 10, color = "green")

ax1.set_title("TryCC_Median_7_ResNet50_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_ResNet50_1', 'Median_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_ResNet50_224_valLoss.png')
files.download("TryCC_Median_7_ResNet50_224_valLoss.png")
plt.show()


# TryCC_Median_7_MobileNet valLoss
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valLoss"] / 10, color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valLoss"] / 10, color = "red")

ax1.set_title("TryCC_Median_7_MobileNet_224 - valLoss")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_MobileNet_224_valLoss.png')
files.download("TryCC_Median_7_MobileNet_224_valLoss.png")
plt.show()

# %%
# TryCC_Gaussian_5_ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valAccuracy"] , color = "red")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valAccuracy"] , color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valAccuracy"] , color = "green")

ax1.set_title("TryCC_Gaussian_5_ResNet50_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_ResNet50_1', 'Gaussian_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_ResNet50_224_valAccuracy.png')
files.download("TryCC_Gaussian_5_ResNet50_224_valAccuracy.png")
plt.show()

# TryCC_Gaussian_5_MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valAccuracy"] , color = "red")

ax1.set_title("TryCC_Gaussian_5_MobileNet_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_MobileNet_224_valAccuracy.png')
files.download("TryCC_Gaussian_5_MobileNet_224_valAccuracy.png")
plt.show()


# TryCC_Gaussian_7_ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valAccuracy"] , color = "red")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valAccuracy"] , color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valAccuracy"] , color = "green")

ax1.set_title("TryCC_Gaussian_7_ResNet50_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_ResNet50_1', 'Gaussian_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_ResNet50_224_valAccuracy.png')
files.download("TryCC_Gaussian_7_ResNet50_224_valAccuracy.png")
plt.show()


# TryCC_Gaussian_7_MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valAccuracy"] , color = "red")

ax1.set_title("TryCC_Gaussian_7_MobileNet_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Gaussian_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_MobileNet_224_valAccuracy.png')
files.download("TryCC_Gaussian_7_MobileNet_224_valAccuracy.png")
plt.show()

# TryCC_Median_5_ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valAccuracy"] , color = "red")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valAccuracy"] , color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valAccuracy"] , color = "green")

ax1.set_title("TryCC_Median_5_ResNet50_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_ResNet50_1', 'Median_5_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_ResNet50_224_valAccuracy.png')
files.download("TryCC_Median_5_ResNet50_224_valAccuracy.png")
plt.show()

# TryCC_Median_5_MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valAccuracy"] , color = "red")

ax1.set_title("TryCC_Median_5_MobileNet_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_5_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_MobileNet_224_valAccuracy.png')
files.download("TryCC_Median_5_MobileNet_224_valAccuracy.png")
plt.show()


# TryCC_Median_7_ResNet50 valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valAccuracy"] , color = "red")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valAccuracy"] , color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valAccuracy"] , color = "green")

ax1.set_title("TryCC_Median_7_ResNet50_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_ResNet50_1', 'Median_7_ResNet50_2'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_ResNet50_224_valAccuracy.png')
files.download("TryCC_Median_7_ResNet50_224_valAccuracy.png")
plt.show()


# TryCC_Median_7_MobileNet valAccuracy
plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valAccuracy"] , color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valAccuracy"] , color = "red")

ax1.set_title("TryCC_Median_7_MobileNet_224 - valAccuracy")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend(labels = ['Median_7_MobileNet_1'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_MobileNet_224_valAccuracy.png')
files.download("TryCC_Median_7_MobileNet_224_valAccuracy.png")
plt.show()

# %%
# TryCC_Gaussian_5_ResNet50_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_1, x=xBar, y=Gaussian_5_dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_5_dfResNet50_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_5_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Gaussian_5_ResNet50_2

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_5_dfResNet50_2, x=xBar, y=Gaussian_5_dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_5_dfResNet50_2")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_5_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryCC_Gaussian_7_ResNet50_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_1, x=xBar, y=Gaussian_7_dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_7_dfResNet50_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_7_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Gaussian_7_ResNet50_2

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_7_dfResNet50_2, x=xBar, y=Gaussian_7_dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_7_dfResNet50_2")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_7_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryCC_Median_5_ResNet50_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=Median_5_dfResNet50_1, x=xBar, y=Median_5_dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_5_dfResNet50_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_5_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Median_5_ResNet50_2

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=Median_5_dfResNet50_2, x=xBar, y=Median_5_dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_5_dfResNet50_2")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_5_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryCC_Median_7_ResNet50_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Accuracy"], color = "green")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valAccuracy"], color = "red")
sns.scatterplot(data=Median_7_dfResNet50_1, x=xBar, y=Median_7_dfResNet50_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_7_dfResNet50_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_7_dfResNet50_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Median_7_ResNet50_2

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Accuracy"], color = "green")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valAccuracy"], color = "red")
sns.scatterplot(data=Median_7_dfResNet50_2, x=xBar, y=Median_7_dfResNet50_2["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_7_dfResNet50_2")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_7_dfResNet50_2_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# %%
# TryCC_Gaussian_5_MobileNet_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_5_dfMobileNet_1, x=[i for i in range(0, 94)], y=Gaussian_5_dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_5_dfMobileNet_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_5_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_5_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Gaussian_7_MobileNet_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=Gaussian_7_dfMobileNet_1, x=[i for i in range(0, 207)], y=Gaussian_7_dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Gaussian_7_dfMobileNet_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Gaussian_7_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Gaussian_7_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Median_5_MobileNet_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=Median_5_dfMobileNet_1, x=[i for i in range(0, 140)], y=Median_5_dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_5_dfMobileNet_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_5_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_5_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()

# TryCC_Median_7_MobileNet_1

plt.figure(figsize=(15, 5))
ax1 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Loss"] /10, color = "blue")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Loss"] /10, color = "blue")

ax2 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Accuracy"], color = "green")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["Accuracy"], color = "green")

ax3 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valLoss"]/10, color = "orange")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valLoss"]/10, color = "orange")

ax4 = sns.lineplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valAccuracy"], color = "red")
sns.scatterplot(data=Median_7_dfMobileNet_1, x=[i for i in range(0, 176)], y=Median_7_dfMobileNet_1["valAccuracy"], color = "red")

ax1.set_title("TryCC_Median_7_dfMobileNet_1")
plt.xlabel("Epoch")
plt.ylabel("")
plt.ylim(0,1)
plt.legend(labels = ['Loss', 'Accuracy', 'valLoss', 'valAccuracy'],loc = 'upper left', prop={'size': 8})
plt.savefig('TryCC_Median_7_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png')
files.download("TryCC_Median_7_dfMobileNet_1_Loss, Accuracy, valLoss, valAccuracy.png")
plt.show()
